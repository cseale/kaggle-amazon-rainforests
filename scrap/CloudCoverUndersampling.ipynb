# %%
import numpy as np
import pandas as pd
import os
from random import shuffle
from tqdm import tqdm

DATA_DIR = '../input/amazon/'
TRAIN_TIF_DIR = DATA_DIR + 'train-tif/'
TRAIN_CSV = DATA_DIR + 'train.csv'
TEST_TIF_DIR = DATA_DIR + 'test-tif/'

IMG_SIZE = 100
LR = 1e-3

MODEL_NAME = 'amazon=-{}-{}.model'.format(LR, '2conv-basic')

CLOUD_COVER_LABELS = [
    'clear', 
    'cloudy', 
    'haze', 
    'partly_cloudy']

# read our data and take a look at what we are dealing with
train_csv = pd.read_csv(TRAIN_CSV)
train_csv.head()

tags = pd.DataFrame()

for label in CLOUD_COVER_LABELS:
    tags[label] = train_csv.tags.apply(lambda x: np.where(label in x, 1, 0))
    
train_csv = pd.concat([train_csv, tags], axis=1)

# %%
pd.concat([train_csv[train_csv.clear == 1].sample(n=7251),
train_csv[train_csv.cloudy == 1].sample(n=7251),
train_csv[train_csv.haze == 1],
train_csv[train_csv.partly_cloudy == 1].sample(n=7251)], axis=0, ignore_index=True)
# Out:
#         image_name                                               tags  clear  \
# 0      train_15881               agriculture clear primary road water      1
# 1       train_6429                                      clear primary      1
# 2      train_15897                                      clear primary      1
# 3       train_4660                    clear primary selective_logging      1
# 4      train_33419                     agriculture clear primary road      1
# 5      train_31639                              clear habitation road      1
# 6      train_26868                                      clear primary      1
# 7      train_26768                          agriculture clear primary      1
# 8      train_27307                                clear primary water      1
# 9      train_36095                                clear primary water      1
# 10      train_8594                                      clear primary      1
# 11     train_30973                                      clear primary      1
# 12     train_26065                     agriculture clear primary road      1
# 13     train_30980                          agriculture clear primary      1
# 14     train_27035              agriculture clear cultivation primary      1
# 15     train_39073                                      clear primary      1
# 16     train_36774                                      clear primary      1
# 17     train_19213                          agriculture clear primary      1
# 18      train_8701                                clear primary water      1
# 19     train_39556                                      clear primary      1
# 20     train_28706  agriculture clear cultivation habitation prima...      1
# 21     train_17979                          agriculture clear primary      1
# 22     train_33652                                      clear primary      1
# 23     train_14608                                      clear primary      1
# 24     train_35116          agriculture clear habitation primary road      1
# 25     train_37012                                      clear primary      1
# 26     train_27614                                      clear primary      1
# 27     train_14859                     agriculture clear primary road      1
# 28      train_3902                 artisinal_mine clear primary water      1
# 29     train_37973                                      clear primary      1
# ...            ...                                                ...    ...
# 24418   train_9371            agriculture partly_cloudy primary water      0
# 24419  train_27056             agriculture partly_cloudy primary road      0
# 24420  train_34493                              partly_cloudy primary      0
# 24421  train_27135                  agriculture partly_cloudy primary      0
# 24422  train_32000                              partly_cloudy primary      0
